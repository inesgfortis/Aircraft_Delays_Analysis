# %%
import pandas as pd
import numpy as np
import pickle

pd.set_option("display.max_columns",None)

# %%
flights = pd.read_csv("flights.csv")
# Out:
# C:\Users\gfine\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3326: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
len(flights)
# Out:
# 5819079

# %%
flights.dropna(subset = ["ORIGIN_AIRPORT"], inplace = True)
len(flights)
# Out:
# 5819079

# %%
flights["ORIGIN_AIRPORT"] = flights["ORIGIN_AIRPORT"].astype(str)
flights["DESTINATION_AIRPORT"] = flights["DESTINATION_AIRPORT"].astype(str)

# %%
flights["code"] = flights["ORIGIN_AIRPORT"] + flights["DESTINATION_AIRPORT"]

# %%
# Buscamos aquellos códigos de aeropuerto que no sean con IATA_CODE tipo str
unknown = flights[flights["code"].str.isdigit()].copy()
unknown.head()
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 4385712  2015     10    1            4      AA           1230      N3DBAA
# 4385713  2015     10    1            4      DL           1805      N696DL
# 4385714  2015     10    1            4      NK            612      N602NK
# 4385715  2015     10    1            4      AA            260      N3GNAA
# 4385716  2015     10    1            4      AA           1982      N914UY
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  \
# 4385712          14747               11298                    5
# 4385713          14771               13487                    5
# 4385714          12889               13487                    5
# 4385715          12892               13303                   10
# 4385716          14771               11057                   10
#
#          DEPARTURE_TIME  DEPARTURE_DELAY  TAXI_OUT  WHEELS_OFF  \
# 4385712            15.0             10.0      15.0        30.0
# 4385713            16.0             11.0      14.0        30.0
# 4385714          2400.0             -5.0      15.0        15.0
# 4385715             7.0             -3.0      28.0        35.0
# 4385716             8.0             -2.0      12.0        20.0
#
#          SCHEDULED_TIME  ELAPSED_TIME  AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN  \
# 4385712           237.0         208.0     189.0      1660      539.0      4.0
# 4385713           213.0         192.0     171.0      1589      521.0      7.0
# 4385714           177.0         168.0     149.0      1299      444.0      4.0
# 4385715           296.0         306.0     271.0      2342      806.0      7.0
# 4385716           291.0         282.0     257.0      2296      737.0     13.0
#
#          SCHEDULED_ARRIVAL  ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# 4385712                602         543.0          -19.0         0          0
# 4385713                538         528.0          -10.0         0          0
# 4385714                502         448.0          -14.0         0          0
# 4385715                806         813.0            7.0         0          0
# 4385716                801         750.0          -11.0         0          0
#
#         CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# 4385712                 NaN               NaN             NaN            NaN
# 4385713                 NaN               NaN             NaN            NaN
# 4385714                 NaN               NaN             NaN            NaN
# 4385715                 NaN               NaN             NaN            NaN
# 4385716                 NaN               NaN             NaN            NaN
#
#          LATE_AIRCRAFT_DELAY  WEATHER_DELAY        code
# 4385712                  NaN            NaN  1474711298
# 4385713                  NaN            NaN  1477113487
# 4385714                  NaN            NaN  1288913487
# 4385715                  NaN            NaN  1289213303
# 4385716                  NaN            NaN  1477111057

# %%
# Hay que clasificar 306 aeropuertos
unknown['ORIGIN_AIRPORT'].nunique()
# Out:
# 306

# %%
unknown = unknown.sort_values('ORIGIN_AIRPORT')
unknown['ORIGIN_AIRPORT'].unique()
# Out:
# array(['10135', '10136', '10140', '10141', '10146', '10154', '10155',
#        '10157', '10158', '10165', '10170', '10185', '10208', '10257',
#        '10268', '10279', '10299', '10333', '10372', '10397', '10408',
#        '10423', '10431', '10434', '10469', '10529', '10551', '10561',
#        '10577', '10581', '10599', '10620', '10627', '10631', '10685',
#        '10693', '10713', '10721', '10728', '10731', '10732', '10739',
#        '10747', '10754', '10779', '10781', '10785', '10792', '10800',
#        '10821', '10849', '10868', '10874', '10918', '10926', '10980',
#        '10990', '10994', '11003', '11013', '11042', '11049', '11057',
#        '11066', '11067', '11076', '11097', '11109', '11111', '11122',
#        '11140', '11146', '11150', '11193', '11203', '11252', '11259',
#        '11267', '11274', '11278', '11292', '11298', '11308', '11315',
#        '11337', '11413', '11423', '11433', '11447', '11471', '11481',
#        '11503', '11525', '11537', '11540', '11577', '11587', '11603',
#        '11612', '11617', '11618', '11624', '11630', '11637', '11638',
#        '11641', '11648', '11695', '11697', '11721', '11775', '11778',
#        '11823', '11865', '11867', '11884', '11898', '11905', '11921',
#        '11953', '11973', '11977', '11980', '11982', '11986', '11995',
#        '11996', '12003', '12007', '12016', '12094', '12129', '12156',
#        '12173', '12177', '12191', '12197', '12206', '12217', '12255',
#        '12264', '12265', '12266', '12278', '12280', '12323', '12335',
#        '12339', '12343', '12389', '12391', '12402', '12441', '12448',
#        '12451', '12478', '12511', '12519', '12523', '12758', '12819',
#        '12884', '12888', '12889', '12891', '12892', '12896', '12898',
#        '12915', '12945', '12951', '12953', '12954', '12982', '12992',
#        '13029', '13061', '13076', '13127', '13158', '13184', '13198',
#        '13204', '13230', '13232', '13241', '13244', '13256', '13264',
#        '13277', '13290', '13296', '13303', '13342', '13344', '13360',
#        '13367', '13377', '13422', '13433', '13459', '13476', '13485',
#        '13486', '13487', '13495', '13502', '13541', '13577', '13795',
#        '13796', '13830', '13851', '13871', '13873', '13891', '13930',
#        '13931', '13933', '13964', '13970', '14006', '14025', '14027',
#        '14057', '14098', '14100', '14107', '14108', '14109', '14113',
#        '14122', '14150', '14193', '14222', '14252', '14254', '14256',
#        '14262', '14307', '14321', '14457', '14487', '14489', '14492',
#        '14520', '14524', '14543', '14570', '14574', '14576', '14588',
#        '14633', '14635', '14674', '14679', '14683', '14685', '14689',
#        '14696', '14698', '14709', '14711', '14730', '14747', '14771',
#        '14783', '14794', '14814', '14828', '14831', '14842', '14843',
#        '14869', '14893', '14905', '14908', '14952', '14960', '14986',
#        '15016', '15024', '15027', '15041', '15048', '15070', '15096',
#        '15249', '15295', '15304', '15323', '15356', '15370', '15376',
#        '15380', '15389', '15401', '15411', '15412', '15497', '15607',
#        '15624', '15841', '15919', '15991', '16218'], dtype=object)

# %%
# Ningun trayecto da lugar a dos distancias diferentes
unknown.groupby("code")["DISTANCE"].nunique().max()
# Out:
# 1

# %%
# Diccionario que relaciona un trayecto y su distancia
dict_flight_distance = dict(zip(unknown["code"],unknown["DISTANCE"]))
dict_flight_distance
# Out:
# {'1474711298': 1660,
#  '1477113487': 1589,
#  '1288913487': 1299,
#  '1289213303': 2342,
#  '1477111057': 2296,
#  '1477113930': 1846,
#  '1289213930': 1744,
#  '1486911057': 1727,
#  '1289211298': 1235,
#  '1289213487': 1535,
#  '1289210693': 1797,
#  '1289211057': 2125,
#  '1029914747': 1448,
#  '1288912266': 1222,
#  '1474713487': 1399,
#  '1477112266': 1635,
#  '1129212478': 1626,
#  '1410711298': 868,
#  '1474713930': 1721,
#  '1029914057': 1542,
#  '1486910397': 1590,
#  '1477111298': 1464,
#  '1289212266': 1379,
#  '1288911298': 1055,
#  '1288913198': 1139,
#  '1129211057': 1337,
0
#
#          SCHEDULED_TIME  ELAPSED_TIME  AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN  \
# 4390906            74.0          76.0      59.0       298     1017.0      8.0
# 4398680            74.0          68.0      54.0       298     1748.0      8.0
# 4407536            74.0          65.0      52.0       298     1102.0      4.0
# 4415293            74.0          77.0      56.0       298     1843.0     10.0
# 4425343            74.0          64.0      50.0       298     1236.0      4.0
#
#          SCHEDULED_ARRIVAL  ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# 4390906               1030        1025.0           -5.0         0          0
# 4398680               1812        1756.0          -16.0         0          0
# 4407536               1030        1106.0           36.0         0          0
# 4415293               1812        1853.0           41.0         0          0
# 4425343               1254        1240.0          -14.0         0          0
#
#         CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# 4390906                 NaN               NaN             NaN            NaN
# 4398680                 NaN               NaN             NaN            NaN
# 4407536                 NaN              36.0             0.0            0.0
# 4415293                 NaN               3.0             0.0            0.0
# 4425343                 NaN               NaN             NaN            NaN
#
#          LATE_AIRCRAFT_DELAY  WEATHER_DELAY        code
# 4390906                  NaN            NaN  1225511292
# 4398680                  NaN            NaN  1225511292
# 4407536                  0.0            0.0  1225511292
# 4415293                 38.0            0.0  1225511292
# 4425343                  NaN            NaN  1225511292

# %%
pocho_dist = flights[flights["DISTANCE"] == 298]
pocho_dist
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 786      2015      1    1            4      OO           5428      N679SA
# 4400     2015      1    1            4      OO           5417      N947SW
# 4414     2015      1    1            4      OO           7381      N675BR
# 6003     2015      1    1            4      OO           7381      N675BR
# 7063     2015      1    1            4      OO           5411      N947SW
# ...       ...    ...  ...          ...     ...            ...         ...
# 5810716  2015     12   31            4      OO           5428      N920SW
# 5811239  2015     12   31            4      OO           7381      N455CA
# 5812803  2015     12   31            4      OO           7381      N455CA
# 5814846  2015     12   31            4      OO           5424      N946SW
# 5816910  2015     12   31            4      OO           5346      N946SW
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  \
# 786                HYS                 DEN                  650
# 4400               DEN                 HYS                 1110
# 4414               SLC                 COD                 1112
# 6003               COD                 SLC                 1252
# 7063               HYS                 DEN                 1357
# ...                ...                 ...                  ...
# 5810716            HYS                 DEN                 1035
# 5811239            SLC                 COD                 1112
# 5812803            COD                 SLC                 1252
# 5814846            DEN                 HYS                 1514
# 5816910            HYS                 DEN                 1753
#
#          DEPARTURE_TIME  DEPARTURE_DELAY  TAXI_OUT  WHEELS_OFF  \
# 786               650.0              0.0      23.0       713.0
# 4400             1100.0            -10.0      10.0      1110.0
# 4414             1112.0              0.0      17.0      1129.0
# 6003             1319.0             27.0       7.0      1326.0
# 7063             1347.0            -10.0       7.0      1354.0
# ...                 ...              ...       ...         ...
# 5810716          1025.0            -10.0       7.0      1032.0
# 5811239          1105.0             -7.0      14.0      1119.0
# 5812803          1245.0             -7.0      36.0      1321.0
# 5814846          1525.0             11.0      14.0      1539.0
# 5816910          1745.0             -8.0      23.0      1808.0
#
#          SCHEDULED_TIME  ELAPSED_TIME  AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN  \
# 786                74.0          85.0      53.0       298      706.0      9.0
# 4400               77.0          64.0      47.0       298     1257.0      7.0
# 4414               75.0          78.0      57.0       298     1226.0      4.0
# 6003               75.0          61.0      48.0       298     1414.0      6.0
# 7063               74.0          63.0      50.0       298     1344.0      6.0
# ...                 ...           ...       ...       ...        ...      ...
# 5810716            80.0          70.0      59.0       298     1031.0      4.0
# 5811239            75.0          67.0      47.0       298     1206.0      6.0
# 5812803            75.0          91.0      50.0       298     1411.0      5.0
# 5814846            67.0          59.0      42.0       298     1721.0      3.0
# 5816910            80.0          88.0      59.0       298     1807.0      6.0
#
#          SCHEDULED_ARRIVAL  ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# 786                    704         715.0           11.0         0          0
# 4400                  1327        1304.0          -23.0         0          0
# 4414                  1227        1230.0            3.0         0          0
# 6003                  1407        1420.0           13.0         0          0
# 7063                  1411        1350.0          -21.0         0          0
# ...                    ...           ...            ...       ...        ...
# 5810716               1055        1035.0          -20.0         0          0
# 5811239               1227        1212.0          -15.0         0          0
# 5812803               1407        1416.0            9.0         0          0
# 5814846               1721        1724.0            3.0         0          0
# 5816910               1813        1813.0            0.0         0          0
#
#         CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# 786                     NaN               NaN             NaN            NaN
# 4400                    NaN               NaN             NaN            NaN
# 4414                    NaN               NaN             NaN            NaN
# 6003                    NaN               NaN             NaN            NaN
# 7063                    NaN               NaN             NaN            NaN
# ...                     ...               ...             ...            ...
# 5810716                 NaN               NaN             NaN            NaN
# 5811239                 NaN               NaN             NaN            NaN
# 5812803                 NaN               NaN             NaN            NaN
# 5814846                 NaN               NaN             NaN            NaN
# 5816910                 NaN               NaN             NaN            NaN
#
#          LATE_AIRCRAFT_DELAY  WEATHER_DELAY    code
# 786                      NaN            NaN  HYSDEN
# 4400                     NaN            NaN  DENHYS
# 4414                     NaN            NaN  SLCCOD
# 6003                     NaN            NaN  CODSLC
# 7063                     NaN            NaN  HYSDEN
# ...                      ...            ...     ...
# 5810716                  NaN            NaN  HYSDEN
# 5811239                  NaN            NaN  SLCCOD
# 5812803                  NaN            NaN  CODSLC
# 5814846                  NaN            NaN  DENHYS
# 5816910                  NaN            NaN  HYSDEN
#
# [2056 rows x 32 columns]

# %%
print(pocho_dist['ORIGIN_AIRPORT'].unique())
print(pocho_dist['DESTINATION_AIRPORT'].unique())
# Out:
# ['HYS' 'DEN' 'SLC' 'COD' 'DCA' 'SYR' '11292' '12255' '14869' '11097']
# ['DEN' 'HYS' 'COD' 'SLC' 'SYR' 'DCA' '12255' '11292' '11097' '14869']

# %%
# Voy a tratar de identificar esta ruta '1474711298'

origen = '14747'
destino = '11298'

# Paso 1: Busco todas las rutas con distancia exactamente igual a 1660

# Pongo que el destino tampoco sea aeropuerto de salida para evitar el trayecto de misma distancia y origen distinto,
# Es decir, el trayecto que sale del aeropuerto 11298 y llega al aeropuerto 14747
rutas = flights[(flights["DISTANCE"] == 1660) & (flights["ORIGIN_AIRPORT"] != origen) & (flights["ORIGIN_AIRPORT"] != destino)].copy()
rutas["ORIGIN_AIRPORT"].value_counts()
# Out:
# DFW    3547
# SEA    3545
# Name: ORIGIN_AIRPORT, dtype: int64

# %% [markdown]
# Busco un codigo de ruta (origen+destino) asociado al orgigen numerico 14747 pero no al destino numerico

# %%
# Con este primer paso tengo ya dos claves que puedo asociar a dos numeros distintos, ahora solo falta saber cual es cual

# Paso 2 Busco otro vuelo que comience con el aeropuerto 14747, voy a elegir solo 1

[path for path in dict_flight_distance.keys() if (path[:5]== origen) & (path[-5:] != destino)][0]
# Out:
# '1474713487'

# %%
# Ahora voy a buscar las rutas alternativas que tengo desde ese aeropuerto
alternativa = flights[(flights["DISTANCE"] == dict_flight_distance['1474713487']) & (flights["ORIGIN_AIRPORT"] != origen) & (flights["ORIGIN_AIRPORT"] != '13487')].copy()
alternativa["ORIGIN_AIRPORT"].value_counts()
# Out:
# MSP    2549
# SEA    2547
# Name: ORIGIN_AIRPORT, dtype: int64

# %% [markdown]
# En este momento, estaría en condiciones de deducir que el código 14747 es el aeropuerto SEA, el código 11298 sería el DFW y
# el código 13487 se lo asociaria a MSP

# %%
# Con este esquema vamos a intentar montar un algoritmo que repita este proceso en todas las rutas disponibles, considerando
# que hay un poco (bastante) más de complejidad en las casuísticas.

# Tenemos por una parte una lista de rutas y tenemos un diccionario que relaciona la ruta con su distancia
dict_flight_distance = dict(zip(unknown["code"],unknown["DISTANCE"]))
paths = [path for path in dict_flight_distance.keys()]

# Creamos una estructura para almacenar los resultados, en este caso un diccionario clave:valor --> numero:aeropuerto
dict_airport = {}

# Elementos base que vamos a utilizar en el algoritmo
path = paths[0]

# Hasta que no sea capaz de clasificar todas las rutas no voy a parar
while paths != []:
    print(path)
    origen = path[:5]
    destino = path[-5:]
    path_inverso = destino + origen
    conjunto_paths = set(paths)
    
    # Primer caso: El origen no se encuentra en el diccionario, es decir, no hay un aeropuerto asociado
    if origen not in dict_airport.keys():
        
        # Busco las opciones de trayecto que me puedo encontrar con esta distancia
        ruta = flights[(flights["DISTANCE"] == dict_flight_distance[path]) & (flights["ORIGIN_AIRPORT"] != origen) & (flights["ORIGIN_AIRPORT"] != destino)].copy()
        opciones = [airport for airport in ruta["ORIGIN_AIRPORT"].unique().tolist() if (not airport.startswith('1')) and (airport not in dict_airport.values())]
        print(f"Las opciones para el origen de la ruta {path} son: {opciones}")
        
        # Si solo existe una opcion para el origen, se la asigno directamente
        # Esto solo puede pasar si el destino ya esta asignado por un path previo
        if len(opciones) == 1:
            dict_airport[origen] = opciones[0]
            
            # Elimino el path resultante ya que origen y destino están ya en el diccionario 
            paths.remove(path)
            
            # Si existe el camino inverso también lo voy a quitar puesto que no merece la pena compararlo
            if path_inverso in paths:
                paths.remove(path_inverso)

        # Si existieran dos o más opciones para el origen buscamos en rutas alternativas posibles puntos comunes
        # como en el ejemplo de arriba
        elif len(opciones) >= 2:
            rutas_alternativas = [path for path in paths if (path[:5]== origen) & (path[-5:] != destino)]

            # Si no existieran rutas alternativas hay que saltar este caso porque tampoco podría encontrar el match de momento
            if rutas_alternativas == []:
                print("No existen más rutas alternativas para este path {}".format(path))
                paths.remove(path)
                paths.append(path)
                path = paths[0]
                continue

            # Busco una ruta alternativa que me permita hacer el match
            
            # Estas dos constantes me sirven para dar cierta seguridad al match, no sirve con tener una ruta alternativa
            # coincidente si no que voy a mirar algunas más
            counter = 0
            coincidencias_requeridas = np.ceil(len(rutas_alternativas)/4)
            for i in range(len(rutas_alternativas)):
                ruta_alternativa = rutas_alternativas[i]
                alternativa = flights[(flights["DISTANCE"] == dict_flight_distance[ruta_alternativa]) & (flights["ORIGIN_AIRPORT"] != origen) & (flights["ORIGIN_AIRPORT"] != ruta_alternativa[-5:])].copy()
                posibilidades = [airport for airport in alternativa["ORIGIN_AIRPORT"].unique().tolist() if (not airport.startswith('1')) and (airport not in dict_airport.values())]
                print(f"Las posibilidades encontradas para el origen de la ruta alternativa {ruta_alternativa} son: {posibilidades}")

                coincidencias = [airport for airport in posibilidades if airport in opciones]
                print(f"Las coincidencias encontradas para el origen en la ruta alternativa {ruta_alternativa} son: {coincidencias}")
                if len(coincidencias) == 1:
                    counter += 1
                    if counter >= coincidencias_requeridas:
                        break
                else:
                    continue
            
        
            print(f"La ruta alternativa final es: {ruta_alternativa}")    

            # Si tras recorrer todas las rutas, no puedo encontrar una que me permita el match, tengo que saltar
            # a otro path, puesto que este no tendría seguridad para inferirlo
            if len(coincidencias) != 1:
                print("No se puede clasificar la ruta {} de momento, por no tener seguridad suficiente con la que hacer match".format(path))
                paths.remove(path)
                paths.append(path)
                path = paths[0]
                continue
         
            # En caso de poder hacer un match para el origen, busco la coincidencia y asigno 
            nuevo_destino = ruta_alternativa[-5:]
            ruta_alternativa_inversa = nuevo_destino + origen

            dict_airport[origen] = coincidencias[0]

            # Si la ruta me lo permite, busco clasificar la otra opción (siempre y cuando haya exactamente dos posibilidades)
            if (destino not in dict_airport.keys()) and (len(opciones) == 2):
                dict_airport[destino] = [airport for airport in opciones if airport != coincidencias[0]][0]
                
                paths.remove(path)
                
                if path_inverso in paths:
                    paths.remove(path_inverso)
            
            # De nuevo, si la ruta alternativa me lo permite, intento clasificar este segundo destino (debe haber exactamente
            # dos posibilidades)
            if (nuevo_destino not in dict_airport.keys()) and (len(posibilidades) == 2):
                dict_airport[nuevo_destino] = [airport for airport in posibilidades if airport != coincidencias[0]][0]

                paths.remove(ruta_alternativa)

                if ruta_alternativa_inversa in paths:
                    paths.remove(ruta_alternativa_inversa)
            
        
    # Segundo caso: Me falta por saber el destino del path    
    elif destino not in dict_airport.keys():
        
        # En este caso entendemos que el origen ya existe dentro del diccionario por lo que realizo la búsqueda para el 
        # destino solamente
        ruta = flights[(flights["DISTANCE"] == dict_flight_distance[path]) & (flights["ORIGIN_AIRPORT"] != origen) & (flights["ORIGIN_AIRPORT"] != destino)].copy()
        opciones = [airport for airport in ruta["ORIGIN_AIRPORT"].unique().tolist() if (not airport.startswith('1')) and (airport not in dict_airport.values())]
        print(f"Las opciones para el destino de la ruta {path} son: {opciones}")
        
        # Razono de la misma manera, si las opciones son más de dos busco una ruta alternativa
        if len(opciones) >= 2:
            # Busco una ruta alternativa que me permita hacer el match con respecto al destino del path
            rutas_alternativas = [path for path in paths if (path[:5]== destino) & (path[-5:] != origen)]
            
            # Si no existieran rutas alternativas hay que saltar este caso porque tampoco podría encontrar el match de momento
            if rutas_alternativas == []:
                print("No existen más rutas alternativas para este path {}".format(path))
                paths.remove(path)
                paths.append(path)
                path = paths[0]
                continue

            counter = 0
            coincidencias_requeridas = np.ceil(len(rutas_alternativas)/4)
            for i in range(len(rutas_alternativas)):
                ruta_alternativa = rutas_alternativas[i]
                alternativa = flights[(flights["DISTANCE"] == dict_flight_distance[ruta_alternativa]) & (flights["ORIGIN_AIRPORT"] != destino) & (flights["ORIGIN_AIRPORT"] != ruta_alternativa[-5:])].copy()
                posibilidades = [airport for airport in alternativa["ORIGIN_AIRPORT"].unique().tolist() if (not airport.startswith('1')) and (airport not in dict_airport.values())]
                print(f"Las posibilidades encontradas para el destino en la ruta alternativa {ruta_alternativa} son: {posibilidades}")
                coincidencias = [airport for airport in posibilidades if airport in opciones]
                print(f"Las coincidencias encontradas para el destino en la ruta alternativa {ruta_alternativa} son: {coincidencias}")
                
                if len(coincidencias) == 1:
                    counter += 1
                    if counter >= coincidencias_requeridas:
                        break
                else:
                    continue
            
            print(f"La ruta alternativa final es: {ruta_alternativa}")   
        
            # Si tras recorrer todas las rutas, no puedo encontrar una que me permita el match, tengo que saltar a otra
            if counter < coincidencias_requeridas:
                print("No se puede clasificar la ruta {} de momento, por no encontrar una ruta alternativa con la que hacer match".format(path))
                paths.remove(path)
                paths.append(path)
                path = paths[0]
                continue
                
            dict_airport[destino] = coincidencias[0]
        
        # Si solo existiera una opcion, se la agrego directamente
        else:
            dict_airport[destino] = opciones[0]

        paths.remove(path)

        if path_inverso in paths:
            paths.remove(path_inverso)
            
    # En el caso de que origen y destino ya hayan sido clasificados por otras rutas diferentes, esta comparación no
    # tiene sentido y solo necesitamos quitarla
    # Ejemplo de este caso: Tengo dos rutas, una que va de A a B y que ha sido clasificada, otra que va de C a D que también
    # ha sido clasificada. Si luego me encuentro la ruta que va de A a C, no necesito clasificarla.
    else:
        paths.remove(path)
        
        if path_inverso in paths:
            paths.remove(path_inverso)
            
    # Mensajes de estado del proceso    
    aeropuertos_clasificados = len(dict_airport.keys())
    rutas_por_clasificar = len(paths)
    path = paths[0]
    print("Aeropuertos clasificados: {}".format(aeropuertos_clasificados))
    print("Rutas por clasificar: {}".format(rutas_por_clasificar))
    
    if len(paths) % 20 == 0:
        print(dict_airport)
# Out:
# 1474711298
# Las opciones para el origen de la ruta 1474711298 son: ['SEA', 'DFW']
# Las posibilidades encontradas para el origen de la ruta alternativa 1474713487 son: ['SEA', 'MSP']
# Las coincidencias encontradas para el origen en la ruta alternativa 1474713487 son: ['SEA']
# Las posibilidades encontradas para el origen de la ruta alternativa 1474713930 son: ['SEA', 'ORD']
# Las coincidencias encontradas para el origen en la ruta alternativa 1474713930 son: ['SEA']
# Las posibilidades encontradas para el origen de la ruta alternativa 1474714107 son: ['SEA', 'PHX', 'STT', 'MIA', 'FLL', 'LGA', 'MCI']
# Las coincidencias encontradas para el origen en la ruta alternativa 1474714107 son: ['SEA']
# Las posibilidades encontradas para el origen de la ruta alternativa 1474714771 son: ['MSO', 'SEA', 'SFO', 'DEN', 'ACY', 'ATL']
# Las coincidencias encontradas para el origen en la ruta alternativa 1474714771 son: ['SEA']
# Las posibilidades encontradas para el origen de la ruta alternativa 1474711292 son: ['SEA', 'DEN', 'SDF', 'GRR', 'MCO']
# Las coincidencias encontradas para el origen en la ruta alternativa 1474711292 son: ['SEA']
# Las posibilidades encontradas para el origen de la ruta alternativa 1474712889 son: ['ORD', 'BOS', 'SEA', 'LAS']
# Las coincidencias encontradas para el origen en la ruta alternativa 1474712889 son: ['SEA']
# Las posibilidades encontradas para el origen de la ruta alternativa 1474712892 son: ['LAX', 'SEA', 'BLI', 'LAS', 'ATL', 'FSD']
# Las coincidencias encontradas para el origen en la ruta alternativa 1474712892 son: ['SEA']
# Las posibilidades encontradas para el origen de la ruta alternativa 1474712266 son: ['SEA', 'EWR', 'IAH', 'JAC']
# Las coincidencias encontradas para el origen en la ruta alternativa 1474712266 son: ['SEA']
# Las posibilidades encontradas para el origen de la ruta alternativa 1474711618 son: ['SEA', 'LAX', 'EWR', 'PHL']
# Las coincidencias encontradas para el origen en la ruta alternativa 1474711618 son: ['SEA']
# Las posibilidades encontradas para el origen de la ruta alternativa 1474714908 son: ['SEA', 'SNA', 'DEN', 'ORD', 'AUS', 'LFT']
# Las coincidencias encontradas para el origen en la ruta alternativa 1474714908 son: ['SEA']
# Las posibilidades encontradas para el origen de la ruta alternativa 1474710299 son: ['ANC', 'SEA', 'MDW', 'BOI']
# Las coincidencias encontradas para el origen en la ruta alternativa 1474710299 son: ['SEA']
# Las posibilidades encontradas para el origen de la ruta alternativa 1474713796 son: ['PIA', 'DFW', 'OAK', 'SEA']
# Las coincidencias encontradas para el origen en la ruta alternativa 1474713796 son: ['DFW', 'SEA']
# Las posibilidades encontradas para el origen de la ruta alternativa 1474714869 son: ['SEA', 'ATL', 'IAH', 'MCI', 'SLC', 'MSY']
# Las coincidencias encontradas para el origen en la ruta alternativa 1474714869 son: ['SEA']
# Las posibilidades encontradas para el origen de la ruta alternativa 1474710397 son: ['SEA', 'ATL']
# Las coincidencias encontradas para el origen en la ruta alternativa 1474710397 son: ['SEA']
# Las posibilidades encontradas para el origen de la ruta alternativa 1474711433 son: ['SEA', 'PHL', 'DTW', 'SLC']
# Las coincidencias encontradas para el origen en la ruta alternativa 1474711433 son: ['SEA']
# Las posibilidades encontradas para el origen de la ruta alternativa 1474710713 son: ['DCA', 'BOS', 'OAJ', 'DTW', 'ANC', 'AVP', 'ATL', 'BET', 'MYR', 'BWI', 'BOI', 'SEA']
# Las coincidencias encontradas para el origen en la ruta alternativa 1474710713 son: ['SEA']
# Las posibilidades encontradas para el origen de la ruta alternativa 1474714831 son: ['SEA', 'SJC']
# Las coincidencias encontradas para el origen en la ruta alternativa 1474714831 son: ['SEA']
# La ruta alternativa final es: 1474714831
# Aeropuertos clasificados: 3
# Rutas por clasificar: 3912
# 1477113487
# Las opciones para el origen de la ruta 1477113487 son: ['SFO', 'MSP']
# Las posibilidades encontradas para el origen de la ruta alternativa 1477111057 son: ['SFO', 'CLT']
# Las coincidencias encontradas para el origen en la ruta alternativa 1477111057 son: ['SFO']
# Las posibilidades encontradas para el origen de la ruta alternativa 1477113930 son: ['SFO', 'ORD', 'CAK', 'LAS']
# Las coincidencias encontradas para el origen en la ruta alternativa 1477113930 son: ['SFO']
# Las posibilidades encontradas para el origen de la ruta alternativa 1477112266 son: ['SFO', 'IAH']
# Las coincidencias encontradas para el origen en la ruta alternativa 1477112266 son: ['SFO']
# Las posibilidades encontradas para el origen de la ruta alternativa 1477111298 son: ['SFO']
# Las coincidencias encontradas para el origen en la ruta alternativa 1477111298 son: ['SFO']
# Las posibilidades encontradas para el origen de la ruta alternativa 1477111292 son: ['SFO', 'MCI', 'DEN', 'BWI']
# Las coincidencias encontradas para el origen en la ruta alternativa 1477111292 son: ['SFO']
# Las posibilidades encontradas para el origen de la ruta alternativa 1477110397 son: ['SFO', 'ATL']
# Las coincidencias encontradas para el origen en la ruta alternativa 1477110397 son: ['SFO']
# Las posibilidades encontradas para el origen de la ruta alternativa 1477112889 son: ['LAS', 'SFO', 'LEX', 'DCA']
# Las coincidencias encontradas para el origen en la ruta alternativa 1477112889 son: ['SFO']
# Las posibilidades encontradas para el origen de la ruta alternativa 1477112892 son: ['SFO', 'LAX', 'OAK', 'BNA', 'RDU', 'CMH', 'BWI', 'PHL']
# Las coincidencias encontradas para el origen en la ruta alternativa 1477112892 son: ['SFO']
# Las posibilidades encontradas para el origen de la ruta alternativa 1477111618 son: ['SFO', 'EWR']
# Las coincidencias encontradas para el origen en la ruta alternativa 1477111618 son: ['SFO']
# Las posibilidades encontradas para el origen de la ruta alternativa 1477112264 son: ['SFO', 'IAD']
# Las coincidencias encontradas para el origen en la ruta alternativa 1477112264 son: ['SFO']
# Las posibilidades encontradas para el origen de la ruta alternativa 1477110721 son: ['BOS', 'SFO']
# Las coincidencias encontradas para el origen en la ruta alternativa 1477110721 son: ['SFO']
# Las posibilidades encontradas para el origen de la ruta alternativa 1477114107 son: ['SFO', 'PHX', 'MSY', 'OMA', 'DAL', 'DEN', 'CLT', 'DTW']
# Las coincidencias encontradas para el origen en la ruta alternativa 1477114107 son: ['SFO']
# Las posibilidades encontradas para el origen de la ruta alternativa 1477112954 son: ['SFO', 'CRP', 'LGB']
# Las coincidencias encontradas para el origen en la ruta alternativa 1477112954 son: ['SFO']
# Las posibilidades encontradas para el origen de la ruta alternativa 1477114100 son: ['SFO', 'PHL', 'JFK', 'SMF']
# Las coincidencias encontradas para el origen en la ruta alternativa 1477114100 son: ['SFO']
# Las posibilidades encontradas para el origen de la ruta alternativa 1477112478 son: ['JFK', 'SFO']
# Las coincidencias encontradas para el origen en la ruta alternativa 1477112478 son: ['SFO']
# Las posibilidades encontradas para el origen de la ruta alternativa 1477114747 son: ['MSO', 'SFO', 'DEN', 'ACY', 'ATL']
# Las coincidencias encontradas para el origen en la ruta alternativa 1477114747 son: ['SFO']
# Las posibilidades encontradas para el origen de la ruta alternativa 1477114679 son: ['CMH', 'SFO', 'MSY', 'SAN', 'ATL']
# Las coincidencias encontradas para el origen en la ruta alternativa 1477114679 son: ['SFO']
# La ruta alternativa final es: 1477114679
# Aeropuertos clasificados: 5
# Rutas por clasificar: 3910
# 1288913487
# Las opciones para el origen de la ruta 1288913487 son: ['LAS']
# Aeropuertos clasificados: 6
# Rutas por clasificar: 3908
# 1289213303
# Las opciones para el origen de la ruta 1289213303 son: ['LAX', 'MIA', 'FLL']
# Las posibilidades encontradas para el origen de la ruta alternativa 1289213930 son: ['LAX', 'ORD']
# Las coincidencias encontradas para el origen en la ruta alternativa 1289213930 son: ['LAX']
# Las posibilidades encontradas para el origen de la ruta alternativa 1289211298 son: ['LAX', 'IAH', 'BWI', 'HOU']
# Las coincidencias encontradas para el origen en la ruta alternativa 1289211298 son: ['LAX']
# Las posibilidades encontradas para el origen de la ruta alternativa 1289213487 son: ['LAX']
# Las coincidencias encontradas para el origen en la ruta alternativa 1289213487 son: ['LAX']
# Las posibilidades encontradas para el origen de la ruta alternativa 1289210693 son: ['BNA', 'LAX']
# Las coincidencias encontradas para el origen en la ruta alternativa 1289210693 son: ['LAX']
# Las posibilidades encontradas para el origen de la ruta alternativa 1289211057 son: ['LAX', 'CLT', 'SLC', 'ANC']
# Las coincidencias encontradas para el origen en la ruta alternativa 1289211057 son: ['LAX']
# Las posibilidades encontradas para el origen de la ruta alternativa 1289212266 son: ['LAX', 'IAH']
# Las coincidencias encontradas para el origen en la ruta alternativa 1289212266 son: ['LAX']
# Las posibilidades encontradas para el origen de la ruta alternativa 1289211292 son: ['DEN', 'LAX', 'GSP', 'IAH']
# Las coincidencias encontradas para el origen en la ruta alternativa 1289211292 son: ['LAX']
# Las posibilidades encontradas para el origen de la ruta alternativa 1289210397 son: ['LAX', 'ATL']
# Las coincidencias encontradas para el origen en la ruta alternativa 1289210397 son: ['LAX']
# Las posibilidades encontradas para el origen de la ruta alternativa 1289214107 son: ['LAX', 'PHX']
# Las coincidencias encontradas para el origen en la ruta alternativa 1289214107 son: ['LAX']
# Las posibilidades encontradas para el origen de la ruta alternativa 1289214771 son: ['LAX', 'OAK', 'BNA', 'RDU', 'CMH', 'BWI', 'PHL']
# Las coincidencias encontradas para el origen en la ruta alternativa 1289214771 son: ['LAX']
# Las posibilidades encontradas para el origen de la ruta alternativa 1289214893 son: ['SMF', 'TTN', 'CVG', 'LAX', 'ATL', 'RDU', 'DTW', 'MLI', 'MSN']
# Las coincidencias encontradas para el origen en la ruta alternativa 1289214893 son: ['LAX']
# Las posibilidades encontradas para el origen de la ruta alternativa 1289214831 son: ['BRO', 'LAX', 'IAH', 'CVG', 'STL']
# Las coincidencias encontradas para el origen en la ruta alternativa 1289214831 son: ['LAX']
# Las posibilidades encontradas para el origen de la ruta alternativa 1289211618 son: ['LAX', 'EWR', 'PDX', 'JFK']
# Las coincidencias encontradas para el origen en la ruta alternativa 1289211618 son: ['LAX']
# Las posibilidades encontradas para el origen de la ruta alternativa 1289212478 son: ['LAX', 'JFK']
# Las coincidencias encontradas para el origen en la ruta alternativa 1289212478 son: ['LAX']
# Las posibilidades encontradas para el origen de la ruta alternativa 1289214747 son: ['LAX', 'BLI', 'ATL', 'FSD']
# Las coincidencias encontradas para el origen en la ruta alternativa 1289214747 son: ['LAX']
# Las posibilidades encontradas para el origen de la ruta alternativa 1289214869 son: ['SLC', 'LAX', 'PBI', 'CLT']
# Las coincidencias encontradas para el origen en la ruta alternativa 1289214869 son: ['LAX']
# Las posibilidades encontradas para el origen de la ruta alternativa 1289212264 son: ['LAX', 'IAD']
# Las coincidencias encontradas para el origen en la ruta alternativa 1289212264 son: ['LAX']
# La ruta alternativa final es: 1289212264
# Aeropuertos clasificados: 8
# Rutas por clasificar: 3906
# 1289213303
# Las opciones para el destino de la ruta 1289213303 son: ['MIA', 'FLL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1330311298 son: ['MIA', 'MCO', 'BOS', 'ABQ', 'MDW']
# Las coincidencias encontradas para el destino en la ruta alternativa 1330311298 son: ['MIA']
# Las posibilidades encontradas para el destino en la ruta alternativa 1330312953 son: ['LGA', 'MIA']
# Las coincidencias encontradas para el destino en la ruta alternativa 1330312953 son: ['MIA']
# Las posibilidades encontradas para el destino en la ruta alternativa 1330311057 son: ['MIA', 'CLT', 'MYR', 'IAG', 'MCI', 'LEX']
# Las coincidencias encontradas para el destino en la ruta alternativa 1330311057 son: ['MIA']
# Las posibilidades encontradas para el destino en la ruta alternativa 1330310397 son: ['HLN', 'MIA', 'DTW', 'ATL', 'GSP', 'ORD', 'EWR', 'MDT', 'DEN']
# Las coincidencias encontradas para el destino en la ruta alternativa 1330310397 son: ['MIA']
# Las posibilidades encontradas para el destino en la ruta alternativa 1330310721 son: ['BOS', 'MIA']
# Las coincidencias encontradas para el destino en la ruta alternativa 1330310721 son: ['MIA']
# Las posibilidades encontradas para el destino en la ruta alternativa 1330313930 son: ['BOS', 'ORD', 'PBI', 'MIA']
# Las coincidencias encontradas para el destino en la ruta alternativa 1330313930 son: ['MIA']
# Las posibilidades encontradas para el destino en la ruta alternativa 1330311278 son: ['DCA', 'MIA', 'BWI', 'RSW', 'DAL', 'CMH']
# Las coincidencias encontradas para el destino en la ruta alternativa 1330311278 son: ['MIA']
# Las posibilidades encontradas para el destino en la ruta alternativa 1330314100 son: ['MIA', 'ASE', 'PHL', 'ORD', 'MSO']
# Las coincidencias encontradas para el destino en la ruta alternativa 1330314100 son: ['MIA']
# Las posibilidades encontradas para el destino en la ruta alternativa 1330314843 son: ['SJU', 'MIA', 'ORF']
# Las coincidencias encontradas para el destino en la ruta alternativa 1330314843 son: ['MIA']
# Las posibilidades encontradas para el destino en la ruta alternativa 1330312889 son: ['MIA']
# Las coincidencias encontradas para el destino en la ruta alternativa 1330312889 son: ['MIA']
# Las posibilidades encontradas para el destino en la ruta alternativa 1330313204 son: ['MCO', 'RNO', 'SHV', 'MIA', 'CAE', 'HOU', 'ATL', 'SAT', 'IAH']
# Las coincidencias encontradas para el destino en la ruta alternativa 1330313204 son: ['MIA']
# Las posibilidades encontradas para el destino en la ruta alternativa 1330312478 son: ['JFK', 'MIA', 'MSY', 'PHL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1330312478 son: ['MIA']
# La ruta alternativa final es: 1330312478
# Aeropuertos clasificados: 9
# Rutas por clasificar: 3904
# 1477111057
# Las opciones para el destino de la ruta 1477111057 son: ['CLT']
# Aeropuertos clasificados: 10
# Rutas por clasificar: 3902
# 1477113930
# Las opciones para el destino de la ruta 1477113930 son: ['ORD', 'CAK']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393013303 son: ['BOS', 'ORD', 'PBI']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393013303 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393011298 son: ['ORF', 'ORD', 'MCO', 'CMH', 'IAH', 'DSM', 'ASE', 'PIA']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393011298 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393014107 son: ['PHX', 'ORD', 'TUS', 'MDW']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393014107 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393012266 son: ['ORD', 'CHS', 'SAV', 'IAH', 'BWI', 'FLL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393012266 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393011697 son: ['ORD', 'MSY', 'JFK', 'FLL', 'SAN', 'DAL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393011697 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393011292 son: ['ORD', 'DEN', 'STL', 'LGA']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393011292 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393010397 son: ['ORD', 'ATL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393010397 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393011057 son: ['ORD', 'SLC']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393011057 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393012953 son: ['ORD', 'LGA', 'SDF']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393012953 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393013204 son: ['TPA', 'JFK', 'ORD', 'MCO', 'FLL', 'IND']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393013204 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393011278 son: ['RDU', 'DCA', 'ORD', 'BOS', 'TPA', 'BNA']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393011278 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393014100 son: ['PHL', 'ORD', 'GUC', 'LGA', 'AGS']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393014100 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393011618 son: ['ORD', 'EWR', 'DCA', 'SDF', 'MCO', 'STL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393011618 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393011042 son: ['MFE', 'IAH', 'CLE', 'ORD']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393011042 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393010431 son: ['AVL', 'ORD', 'MCI']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393010431 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393013487 son: ['ORD']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393013487 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393011066 son: ['LIT', 'CMH', 'BUR', 'SYR', 'ORD', 'DTW', 'DAL', 'LGA', 'ORF', 'ATW', 'ROC', 'LEX']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393011066 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393010994 son: ['JFK', 'ORD', 'ATL', 'CHS']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393010994 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393010721 son: ['ORD', 'BOS']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393010721 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393014747 son: ['ORD']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393014747 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393011193 son: ['ROC', 'JFK', 'CVG', 'ORD']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393011193 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393010423 son: ['IND', 'ACY', 'BIS', 'FLL', 'DEN', 'DAL', 'CHS', 'AUS', 'ORD']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393010423 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393010821 son: ['BWI', 'MGM', 'CLE', 'ORD']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393010821 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393013184 son: ['ORD', 'SUN', 'MBS', 'SLC']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393013184 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393010599 son: ['SLC', 'MDW', 'ORD', 'BHM']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393010599 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393012339 son: ['FLL', 'ORD', 'MCO', 'IND', 'ROA']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393012339 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393012889 son: ['ORD']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393012889 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393011986 son: ['GRR', 'ORD', 'STL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393011986 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393011423 son: ['ORD', 'DSM', 'CMH']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393011423 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393013244 son: ['MEM', 'ORD', 'BNA', 'MCI', 'FNT']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393013244 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393014574 son: ['ROA', 'SLC', 'FCA', 'ORD']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393014574 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393012992 son: ['LIT', 'ORD']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393012992 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393011433 son: ['ORD', 'DTW']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393011433 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393012264 son: ['OAK', 'LGB', 'SLC', 'SNA', 'ICT', 'ORD', 'PHL', 'IND']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393012264 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393014122 son: ['BOS', 'ORD', 'PIT', 'MDT', 'CVG', 'RIC']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393014122 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393012478 son: ['JFK', 'ORD']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393012478 son: ['ORD']
# Las posibilidades encontradas para el destino en la ruta alternativa 1393011003 son: ['CID', 'MTJ', 'DEN', 'FSD', 'ORD', 'JFK', 'HYA', 'BDL', 'PHL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1393011003 son: ['ORD']
# La ruta alternativa final es: 1393011003
# Aeropuertos clasificados: 11
# Rutas por clasificar: 3900
# {'14747': 'SEA', '11298': 'DFW', '14831': 'SJC', '14771': 'SFO', '13487': 'MSP', '12889': 'LAS', '12892': 'LAX', '12264': 'IAD', '13303': 'MIA', '11057': 'CLT', '13930': 'ORD'}
# 1289213930
# Aeropuertos clasificados: 11
# Rutas por clasificar: 3898
# 1486911057
# Las opciones para el origen de la ruta 1486911057 son: ['SLC']
# Aeropuertos clasificados: 12
# Rutas por clasificar: 3896
# 1289211298
# Aeropuertos clasificados: 12
# Rutas por clasificar: 3894
# 1289213487
# Aeropuertos clasificados: 12
# Rutas por clasificar: 3892
# 1289210693
# Las opciones para el destino de la ruta 1289210693 son: ['BNA']
# Aeropuertos clasificados: 13
# Rutas por clasificar: 3890
# 1289211057
# Aeropuertos clasificados: 13
# Rutas por clasificar: 3888
# 1029914747
# Las opciones para el origen de la ruta 1029914747 son: ['ANC', 'MDW', 'BOI']
# Las posibilidades encontradas para el origen de la ruta alternativa 1029914057 son: ['ANC', 'PDX']
# Las coincidencias encontradas para el origen en la ruta alternativa 1029914057 son: ['ANC']
# Las posibilidades encontradas para el origen de la ruta alternativa 1029913487 son: ['ANC']
# Las coincidencias encontradas para el origen en la ruta alternativa 1029913487 son: ['ANC']
# Las posibilidades encontradas para el origen de la ruta alternativa 1029910551 son: ['DCA', 'BOS', 'OAJ', 'DTW', 'ANC', 'AVP', 'ATL', 'BET', 'MYR', 'BWI', 'BOI']
# Las coincidencias encontradas para el origen en la ruta alternativa 1029910551 son: ['ANC', 'BOI']
# Las posibilidades encontradas para el origen de la ruta alternativa 1029913970 son: ['ANC', 'OTZ']
# Las coincidencias encontradas para el origen en la ruta alternativa 1029913970 son: ['ANC']
# Las posibilidades encontradas para el origen de la ruta alternativa 1029914709 son: ['FAR', 'ANC', 'DEN', 'SCC']
# Las coincidencias encontradas para el origen en la ruta alternativa 1029914709 son: ['ANC']
# Las posibilidades encontradas para el origen de la ruta alternativa 1029912523 son: ['JNU', 'ANC', 'HOU', 'ECP']
# Las coincidencias encontradas para el origen en la ruta alternativa 1029912523 son: ['ANC']
# La ruta alternativa final es: 1029912523
# Aeropuertos clasificados: 14
# Rutas por clasificar: 3888
# 1029914747
# Aeropuertos clasificados: 14
# Rutas por clasificar: 3886
# 1288912266
# Las opciones para el destino de la ruta 1288912266 son: ['IAH', 'OKC']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226613303 son: ['IAH', 'MFR', 'COS', 'DEN']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226613303 son: ['IAH']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226611057 son: ['IAH', 'LIT', 'BWI']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226611057 son: ['IAH']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226613930 son: ['CHS', 'SAV', 'IAH', 'BWI', 'FLL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226613930 son: ['IAH']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226610397 son: ['ATL', 'IAH', 'MCI', 'MSY']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226610397 son: ['IAH']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226614107 son: ['PDX', 'PHX', 'IAH', 'HDN']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226614107 son: ['IAH']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226614771 son: ['IAH']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226614771 son: ['IAH']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226613487 son: ['IAH', 'ISP', 'TPA', 'EWR', 'SRQ']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226613487 son: ['IAH']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226614100 son: ['PHL', 'IAH', 'OKC', 'EWR']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226614100 son: ['IAH', 'OKC']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226611298 son: ['GEG', 'IAH', 'TVC', 'RDU']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226611298 son: ['IAH']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226611618 son: ['EWR', 'IAH']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226611618 son: ['IAH']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226611433 son: ['DTW', 'IAH', 'MKE', 'TPA']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226611433 son: ['IAH']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226613256 son: ['MFE', 'IAH', 'CLE']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226613256 son: ['IAH']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226613158 son: ['MAF', 'TUL', 'IAH']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226613158 son: ['IAH']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226612448 son: ['DRO', 'LFT', 'JAN', 'PHX', 'STL', 'IAH', 'TUL', 'EUG', 'BOI']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226612448 son: ['IAH']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226612953 son: ['LGA', 'RSW', 'IAH', 'MEM']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226612953 son: ['IAH']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226613495 son: ['MSY', 'IAH', 'LGA', 'CHO']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226613495 son: ['IAH']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226610721 son: ['BOS', 'IAH']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226610721 son: ['IAH']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226610781 son: ['BTR', 'IAH', 'ADQ']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226610781 son: ['IAH']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226611697 son: ['PIT', 'RSW', 'FLL', 'IAH', 'MSN']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226611697 son: ['IAH']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226613422 son: ['RDU', 'IND', 'JFK', 'MOB', 'IAH']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226613422 son: ['IAH']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226613198 son: ['MCI', 'IAH']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226613198 son: ['IAH']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226614492 son: ['RDU', 'IAH', 'GRR', 'AUS']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226614492 son: ['IAH']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226613851 son: ['BOS', 'OKC', 'BUF', 'MDW', 'IAH']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226613851 son: ['OKC', 'IAH']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226612892 son: ['IAH']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226612892 son: ['IAH']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226611042 son: ['CLE', 'MCO', 'IAH', 'ORH']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226611042 son: ['IAH']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226612992 son: ['LIT', 'IAH', 'DTW', 'SYR']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226612992 son: ['IAH']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226612339 son: ['FAT', 'IAH', 'DEN', 'IND']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226612339 son: ['IAH']
# Las posibilidades encontradas para el destino en la ruta alternativa 1226612264 son: ['IAH']
# Las coincidencias encontradas para el destino en la ruta alternativa 1226612264 son: ['IAH']
# La ruta alternativa final es: 1226612264
# Aeropuertos clasificados: 15
# Rutas por clasificar: 3884
# 1474713487
# Aeropuertos clasificados: 15
# Rutas por clasificar: 3882
# 1477112266
# Aeropuertos clasificados: 15
# Rutas por clasificar: 3880
# {'14747': 'SEA', '11298': 'DFW', '14831': 'SJC', '14771': 'SFO', '13487': 'MSP', '12889': 'LAS', '12892': 'LAX', '12264': 'IAD', '13303': 'MIA', '11057': 'CLT', '13930': 'ORD', '14869': 'SLC', '10693': 'BNA', '10299': 'ANC', '12266': 'IAH'}
# 1129212478
# Las opciones para el origen de la ruta 1129212478 son: ['DEN', 'JFK', 'DAL', 'PDX']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129211057 son: ['DEN']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129211057 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129213232 son: ['CLE', 'MCO', 'MDW', 'DEN', 'PWM']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129213232 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129215016 son: ['DEN', 'STL']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129215016 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129214107 son: ['DEN', 'PHX']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129214107 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129211298 son: ['DEN', 'VPS', 'BWI', 'MKE', 'LGA', 'CHS']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129211298 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129213930 son: ['DEN', 'STL', 'LGA']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129213930 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129211618 son: ['EWR', 'DEN', 'PHL', 'STT']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129211618 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129212266 son: ['DEN', 'GSP']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129212266 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129211259 son: ['PHX', 'MSY', 'OMA', 'DAL', 'DEN', 'DTW']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129211259 son: ['DAL', 'DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129212191 son: ['PBI', 'BWI', 'HOU', 'DEN']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129212191 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129210397 son: ['DEN', 'ATL']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129210397 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129212264 son: ['DEN']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129212264 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129213487 son: ['DEN', 'KTN', 'RDU', 'FLL']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129213487 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129214771 son: ['MCI', 'DEN', 'BWI']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129214771 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129210693 son: ['DEN']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129210693 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129210821 son: ['BWI', 'DEN']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129210821 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129214869 son: ['COD', 'DEN', 'PNS', 'RNO']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129214869 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129213198 son: ['MCI', 'EWR', 'DEN', 'DAY', 'ATL', 'BMI', 'DTW', 'DSM']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129213198 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129211433 son: ['DEN', 'DTW', 'ATL', 'FAR']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129211433 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129213204 son: ['DEN', 'MCO']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129213204 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129215304 son: ['TPA', 'SDF', 'PHX', 'DEN']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129215304 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129212892 son: ['DEN', 'GSP']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129212892 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129214100 son: ['PHL', 'DEN']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129214100 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129210423 son: ['AUS', 'DEN', 'LBB']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129210423 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129214679 son: ['MKE', 'SAN', 'DEN', 'ALB', 'ATL', 'HOU', 'RSW']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129214679 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129212889 son: ['CHS', 'DEN', 'EWR', 'ABQ', 'SAN']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129212889 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129211278 son: ['DCA', 'DEN', 'DAL', 'AUS']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129211278 son: ['DEN', 'DAL']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129212255 son: ['HYS', 'DEN', 'COD', 'DCA', 'SYR']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129212255 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129214747 son: ['DEN', 'SDF', 'GRR', 'MCO']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129214747 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129214057 son: ['PDX', 'DEN', 'RSW', 'CAK']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129214057 son: ['PDX', 'DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129210721 son: ['BOS', 'DEN']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129210721 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129210713 son: ['BOI', 'DEN']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129210713 son: ['DEN']
# Las posibilidades encontradas para el origen de la ruta alternativa 1129214893 son: ['SMF', 'DEN', 'JNU']
# Las coincidencias encontradas para el origen en la ruta alternativa 1129214893 son: ['DEN']
# La ruta alternativa final es: 1129214893
# Aeropuertos clasificados: 16
# Rutas por clasificar: 3880
# {'14747': 'SEA', '11298': 'DFW', '14831': 'SJC', '14771': 'SFO', '13487': 'MSP', '12889': 'LAS', '12892': 'LAX', '12264': 'IAD', '13303': 'MIA', '11057': 'CLT', '13930': 'ORD', '14869': 'SLC', '10693': 'BNA', '10299': 'ANC', '12266': 'IAH', '11292': 'DEN'}
# 1129212478
# Las opciones para el destino de la ruta 1129212478 son: ['JFK', 'DAL', 'PDX']
# Las posibilidades encontradas para el destino en la ruta alternativa 1247810732 son: ['JFK', 'BQN', 'PHL', 'SJU']
# Las coincidencias encontradas para el destino en la ruta alternativa 1247810732 son: ['JFK']
# Las posibilidades encontradas para el destino en la ruta alternativa 1247814843 son: ['SJU', 'JFK']
# Las coincidencias encontradas para el destino en la ruta alternativa 1247814843 son: ['JFK']
# Las posibilidades encontradas para el destino en la ruta alternativa 1247813303 son: ['JFK', 'MSY', 'PHL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1247813303 son: ['JFK']
# Las posibilidades encontradas para el destino en la ruta alternativa 1247814771 son: ['JFK']
# Las coincidencias encontradas para el destino en la ruta alternativa 1247814771 son: ['JFK']
# Las posibilidades encontradas para el destino en la ruta alternativa 1247812892 son: ['JFK']
# Las coincidencias encontradas para el destino en la ruta alternativa 1247812892 son: ['JFK']
# Las posibilidades encontradas para el destino en la ruta alternativa 1247813204 son: ['JFK', 'MCO']
# Las coincidencias encontradas para el destino en la ruta alternativa 1247813204 son: ['JFK']
# Las posibilidades encontradas para el destino en la ruta alternativa 1247810792 son: ['BUF', 'SCE', 'JFK', 'LRD', 'DTW']
# Las coincidencias encontradas para el destino en la ruta alternativa 1247810792 son: ['JFK']
# Las posibilidades encontradas para el destino en la ruta alternativa 1247810397 son: ['JFK', 'ATL', 'CHS']
# Las coincidencias encontradas para el destino en la ruta alternativa 1247810397 son: ['JFK']
# Las posibilidades encontradas para el destino en la ruta alternativa 1247810721 son: ['BOS', 'JFK', 'HOU', 'CRP']
# Las coincidencias encontradas para el destino en la ruta alternativa 1247810721 son: ['JFK']
# Las posibilidades encontradas para el destino en la ruta alternativa 1247811298 son: ['JFK', 'ATL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1247811298 son: ['JFK']
# Las posibilidades encontradas para el destino en la ruta alternativa 1247811057 son: ['PSP', 'JFK', 'TUL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1247811057 son: ['JFK']
# Las posibilidades encontradas para el destino en la ruta alternativa 1247814027 son: ['PBI', 'JFK', 'TTN', 'RSW']
# Las coincidencias encontradas para el destino en la ruta alternativa 1247814027 son: ['JFK']
# Las posibilidades encontradas para el destino en la ruta alternativa 1247813495 son: ['MSY', 'JFK', 'FLL', 'SAN', 'DAL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1247813495 son: ['JFK', 'DAL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1247812889 son: ['JFK']
# Las coincidencias encontradas para el destino en la ruta alternativa 1247812889 son: ['JFK']
# Las posibilidades encontradas para el destino en la ruta alternativa 1247814107 son: ['JFK', 'PHX']
# Las coincidencias encontradas para el destino en la ruta alternativa 1247814107 son: ['JFK']
# Las posibilidades encontradas para el destino en la ruta alternativa 1247810994 son: ['JFK', 'CHS', 'DTW', 'MYR']
# Las coincidencias encontradas para el destino en la ruta alternativa 1247810994 son: ['JFK']
# La ruta alternativa final es: 1247810994
# Aeropuertos clasificados: 17
# Rutas por clasificar: 3878
# 1410711298
# Las opciones para el origen de la ruta 1410711298 son: ['PHX']
# Aeropuertos clasificados: 18
# Rutas por clasificar: 3876
# 1474713930
# Aeropuertos clasificados: 18
# Rutas por clasificar: 3874
# 1029914057
# Las opciones para el destino de la ruta 1029914057 son: ['PDX']
# Aeropuertos clasificados: 19
# Rutas por clasificar: 3872
# 1486910397
# Las opciones para el destino de la ruta 1486910397 son: ['ATL', 'IND']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039710821 son: ['BWI', 'ATL', 'MDW', 'GSP']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039710821 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039713232 son: ['ATL', 'MDW']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039713232 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039712191 son: ['HOU', 'ATL', 'STL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039712191 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039711057 son: ['ATL', 'SNA']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039711057 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039711259 son: ['ATL', 'DAL', 'EGE', 'AUS', 'STL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039711259 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039711298 son: ['ATL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039711298 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039712953 son: ['LGA', 'ATL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039712953 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039713204 son: ['CLE', 'MCO', 'ATL', 'GCK', 'EWR', 'SNA', 'SMF']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039713204 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039713487 son: ['ATL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039713487 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039712889 son: ['ATL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039712889 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039713303 son: ['HLN', 'DTW', 'ATL', 'GSP', 'EWR', 'MDT']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039713303 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039711618 son: ['EWR', 'ATL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039711618 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039714100 son: ['PHL', 'ATL', 'MCI', 'HOU', 'MTJ', 'CAE']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039714100 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039711697 son: ['FLL', 'ATL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039711697 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039714747 son: ['ATL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039714747 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039713930 son: ['ATL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039713930 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039711292 son: ['ATL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039711292 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039714635 son: ['RSW', 'ATL', 'SAV']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039714635 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039714771 son: ['ATL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039714771 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039712892 son: ['ATL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039712892 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039712264 son: ['ATL', 'RDU', 'DTW', 'MCO', 'DSM']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039712264 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039714122 son: ['PIT', 'ATL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039714122 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039712451 son: ['BPT', 'JAX', 'ATL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039712451 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039713931 son: ['BIS', 'ORF', 'IND', 'ATL', 'BWI']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039713931 son: ['IND', 'ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039711193 son: ['SMF', 'TTN', 'CVG', 'ATL', 'RDU', 'DTW', 'MLI', 'MSN']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039711193 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039714524 son: ['RIC', 'ATL', 'DIK']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039714524 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039711278 son: ['DCA', 'ATL']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039711278 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039712266 son: ['ATL', 'MCI', 'MSY']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039712266 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039714492 son: ['RDU', 'ATL', 'MYR', 'CRW', 'DCA', 'PVD']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039714492 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039710529 son: ['BDL', 'FWA', 'ATL', 'MEM', 'SNA', 'PBI']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039710529 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039712197 son: ['ATL', 'HPN', 'MMH']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039712197 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039711433 son: ['HLN', 'DTW', 'ATL', 'GSP', 'EWR', 'MDT']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039711433 son: ['ATL']
# Las posibilidades encontradas para el destino en la ruta alternativa 1039710721 son: ['BWI', 'BOS', 'MEM', 'EWR', 'ATL', 'CRW']
# Las coincidencias encontradas para el destino en la ruta alternativa 1039710721 son: ['ATL']
# ...
# 1129212888
# Las opciones para el destino de la ruta 1129212888 son: ['SPS', 'LAR']
# No existen más rutas alternativas para este path 1129212888
# 1486915389
# Las opciones para el destino de la ruta 1486915389 son: ['TWF', 'CWA']
# No existen más rutas alternativas para este path 1486915389
# 1143311013
# Las opciones para el destino de la ruta 1143311013 son: ['CIU', 'GFK']
# No existen más rutas alternativas para este path 1143311013
# 1393011203
# Las opciones para el destino de la ruta 1393011203 son: ['TOL', 'CWA']
# No existen más rutas alternativas para este path 1393011203
# 1109714869
# Las opciones para el origen de la ruta 1109714869 son: ['HYS', 'COD']
# No existen más rutas alternativas para este path 1109714869
# 1477114487
# Las opciones para el destino de la ruta 1477114487 son: ['BJI', 'RDD']
# No existen más rutas alternativas para este path 1477114487
# 1129213502
# Las opciones para el destino de la ruta 1129213502 son: ['MTJ', 'HYA']
# No existen más rutas alternativas para este path 1129213502
# 1350211292
# Las opciones para el origen de la ruta 1350211292 son: ['MTJ', 'HYA']
# No existen más rutas alternativas para este path 1350211292
# 1448714771
# Las opciones para el origen de la ruta 1448714771 son: ['BJI', 'RDD']
# No existen más rutas alternativas para este path 1448714771
# 1063113487
# Las opciones para el origen de la ruta 1063113487 son: ['BJI', 'RDD']
# No existen más rutas alternativas para este path 1063113487
# 1289111298
# Las opciones para el origen de la ruta 1289111298 son: ['LAW', 'GGG']
# No existen más rutas alternativas para este path 1289111298
# 1496011298
# Las opciones para el origen de la ruta 1496011298 son: ['SPS', 'LAR']
# No existen más rutas alternativas para este path 1496011298
# 1120313930
# Las opciones para el origen de la ruta 1120313930 son: ['TOL', 'CWA']
# No existen más rutas alternativas para este path 1120313930
# 1379510397
# Las opciones para el origen de la ruta 1379510397 son: ['OAJ', 'BET']
# No existen más rutas alternativas para este path 1379510397
# 1529513930
# Las opciones para el origen de la ruta 1529513930 son: ['TOL', 'CWA']
# No existen más rutas alternativas para este path 
son: ['HYS', 'COD']
# No existen más rutas alternativas para este path 1225511292
# 1190511298
# Las opciones para el origen de la ruta 1190511298 son: ['LAW', 'GGG']
# No existen más rutas alternativas para este path 1190511298
# 1486911097
# Las opciones para el destino de la ruta 1486911097 son: ['HYS', 'COD']
# No existen más rutas alternativas para este path 1486911097
# 1348710631
# Las opciones para el destino de la ruta 1348710631 son: ['BJI', 'RDD']
# No existen más rutas alternativas para este path 1348710631
# 1129212888
# Las opciones para el destino de la ruta 1129212888 son: ['SPS', 'LAR']
# No existen más rutas alternativas para este path 1129212888
# 1486915389
# Las opciones para el destino de la ruta 1486915389 son: ['TWF', 'CWA']
# No existen más rutas alternativas para este path 1486915389
# 1143311013
# Las opciones para el destino de la ruta 1143311013 son: ['CIU', 'GFK']
# No existen más rutas alternativas para este path 1143311013
# 1393011203
# Las opciones para el destino de la ruta 1393011203 son: ['TOL', 'CWA']
# No existen más rutas alternativas para este path 1393011203
# 1109714869
# Las opciones para el origen de la ruta 1109714869 son: ['HYS', 'COD']
# No existen más rutas alternativas para este path 1109714869
# 1477114487
# Las opciones para el destino de la ruta 1477114487 son: ['BJI', 'RDD']
# No existen más rutas alternativas para este path 1477114487
# 1129213502
# Las opciones para el destino de la ruta 1129213502 son: ['MTJ', 'HYA']
# No existen más rutas alternativas para este path 1129213502
# 1350211292
# Las opciones para el origen de la ruta 1350211292 son: ['MTJ', 'HYA']
# No existen más rutas alternativas para este path 1350211292
# 1448714771
# Las opciones para el origen de la ruta 1448714771 son: ['BJI', 'RDD']
# No existen más rutas alternativas para este path 1448714771
# 1063113487
# Las opciones para el origen de la ruta 1063113487 son: ['BJI', 'RDD']
# No existen más rutas alternativas para este path 1063113487
# 1289111298
# Las opciones para el origen de la ruta 1289111298 son: ['LAW', 'GGG']
# No existen más rutas alternativas para este path 1289111298
# 1496011298
# Las opciones para el origen de la ruta 1496011298 son: ['SPS', 'LAR']
# No existen más rutas alternativas para este path 1496011298
# 1120313930
# Las opciones para el origen de la ruta 1120313930 son: ['TOL', 'CWA']
# No existen más rutas alternativas para este path 1120313930
# 1379510397
# Las opciones para el origen de la ruta 1379510397 son: ['OAJ', 'BET']
# No existen más rutas alternativas para este path 1379510397
# 1529513930
# Las opciones para el origen de la ruta 1529513930 son: ['TOL', 'CWA']
# No existen más rutas alternativas para este path 1529513930
# 1288811292
# Las opciones para el origen de la ruta 1288811292 son: ['SPS', 'LAR']
# No existen más rutas alternativas para este path 1288811292
# 1029910551
# Las opciones para el destino de la ruta 1029910551 son: ['OAJ', 'BET']
# No existen más rutas alternativas para este path 1029910551
# 1538914869
# Las opciones para el origen de la ruta 1538914869 son: ['TWF', 'CWA']
# No existen más rutas alternativas para este path 1538914869
# 1101311433
# Las opciones para el origen de la ruta 1101311433 son: ['CIU', 'GFK']
# No existen más rutas alternativas para este path 1101311433
# 1129212255
# Las opciones para el destino de la ruta 1129212255 son: ['HYS', 'COD']
# No existen más rutas alternativas para este path 1129212255
# 1189813487
# Las opciones para el origen de la ruta 1189813487 son: ['CIU', 'GFK']
# No existen más rutas alternativas para este path 1189813487
# 1393015295
# Las opciones para el destino de la ruta 1393015295 son: ['TOL', 'CWA']
# No existen más rutas alternativas para este path 1393015295
# 1055110299
# Las opciones para el origen de la ruta 1055110299 son: ['OAJ', 'BET']
# No existen más rutas alternativas para este path 1055110299
# 1129812891
# Las opciones para el destino de la ruta 1129812891 son: ['LAW', 'GGG']
# No existen más rutas alternativas para este path 1129812891
# 1129811905
# Las opciones para el destino de la ruta 1129811905 son: ['LAW', 'GGG']
# No existen más rutas alternativas para este path 1129811905
# 1129814960
# Las opciones para el destino de la ruta 1129814960 son: ['SPS', 'LAR']
# No existen más rutas alternativas para este path 1129814960
# 1039713795
# Las opciones para el destino de la ruta 1039713795 son: ['OAJ', 'BET']
# No existen más rutas alternativas para este path 1039713795
# 1348711898
# Las opciones para el destino de la ruta 1348711898 son: ['CIU', 'GFK']
# No existen más rutas alternativas para este path 1348711898
# 1225511292
# Las opciones para el origen de la ruta 1225511292 son: ['HYS', 'COD']
# No existen más rutas alternativas para este path 1225511292
# 1190511298
# Las opciones para el origen de la ruta 1190511298 son: ['LAW', 'GGG']
# No existen más rutas alternativas para este path 1190511298
# 1486911097
# Las opciones para el destino de la ruta 1486911097 son: ['HYS', 'COD']
# No existen más rutas alternativas para este path 1486911097
# 1348710631
# Las opciones para el destino de la ruta 1348710631 son: ['BJI', 'RDD']
# No existen más rutas alternativas para este path 1348710631
# 1129212888
# Las opciones para el destino de la ruta 1129212888 son: ['SPS', 'LAR']
# No existen más rutas alternativas para este path 1129212888
# 1486915389
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-8cf04bd38911> in <module>
#     117         # En este caso entendemos que el origen ya existe dentro del diccionario por lo que realizo la búsqueda para el
#     118         # destino solamente
# --> 119         ruta = flights[(flights["DISTANCE"] == dict_flight_distance[path]) & (flights["ORIGIN_AIRPORT"] != origen) & (flights["ORIGIN_AIRPORT"] != destino)].copy()
#     120         opciones = [airport for airport in ruta["ORIGIN_AIRPORT"].unique().tolist() if (not airport.startswith('1')) and (airport not in dict_airport.values())]
#     121         print(f"Las opciones para el destino de la ruta {path} son: {opciones}")
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~\Anaconda3\lib\site-packages\pandas\core\arraylike.py in __and__(self, other)
#      60     @unpack_zerodim_and_defer("__and__")
#      61     def __and__(self, other):
# ---> 62         return self._logical_method(other, operator.and_)
#      63
#      64     @unpack_zerodim_and_defer("__rand__")
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _logical_method(self, other, op)
#    5511         rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    5512
# -> 5513         res_values = ops.logical_op(lvalues, rvalues, op)
#    5514         return self._construct_result(res_values, name=res_name)
#    5515
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in logical_op(left, right, op)
#     380         if isinstance(rvalues, np.ndarray):
#     381             is_other_int_dtype = is_integer_dtype(rvalues.dtype)
# --> 382             rvalues = rvalues if is_other_int_dtype else fill_bool(rvalues, lvalues)
#     383
#     384         else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in fill_bool(x, left)
#     359
#     360         if left is None or is_bool_dtype(left.dtype):
# --> 361             x = x.astype(bool)
#     362         return x
#     363
#
# KeyboardInterrupt:

# %%
dict_airport
# Out:
# {'14747': 'SEA',
#  '11298': 'DFW',
#  '14831': 'SJC',
#  '14771': 'SFO',
#  '13487': 'MSP',
#  '12889': 'LAS',
#  '12892': 'LAX',
#  '12264': 'IAD',
#  '13303': 'MIA',
#  '11057': 'CLT',
#  '13930': 'ORD',
#  '14869': 'SLC',
#  '10693': 'BNA',
#  '10299': 'ANC',
#  '12266': 'IAH',
#  '11292': 'DEN',
#  '12478': 'JFK',
#  '14107': 'PHX',
#  '14057': 'PDX',
#  '10397': 'ATL',
#  '13198': 'MCI',
#  '11630': 'FAI',
#  '12173': 'HNL',
#  '10732': 'BQN',
#  '11618': 'EWR',
#  '14254': 'PSE',
#  '13204': 'MCO',
#  '10627': 'BIS',
#  '11982': 'GRK',
#  '12402': 'ITO',
#  '14683': 'SAT',
#  '10721': 'BOS',
#  '11884': 'GEG',
#  '15919': 'XNA',
#  '13851': 'OKC',
#  '11111': 'COU',
#  '12191': 'HOU',
#  '14783': 'SGF',
#  '15016': 'STL',
#  '12758': 'KOA',
#  '13830': 'OGG',
#  '10423': 'AUS',
#  '15370': 'TUL',
#  '11953': 'GNV',
#  '13891': 'ONT',
#  '15376': 'TUS',
#  '11778': 'FSM',
#  '11278': 'DCA',
#  '14100': 'PHL',
#  '15304': 'TPA',
#  '11637': 'FAR',
#  '11775': 'FSD',
#  '12982': 'LIH',
#  '13931': 'ORF',
#  '10821': 'BWI',
#  '14122': 'PIT',
#  '10990': 'CHO',
#  '13158': 'MAF',
#  '14108': 'PIA',
#  '11697': 'FLL',
#  '11447': 'DVL',
#  '12519': 'JMS',
#  '12206': 'HRL',
#  '13495': 'MSY',
#  '15624': 'VPS',
#  '10747': 'BRO',
#  '15411': 'TYR',
#  '10994': 'CHS',
#  '13256': 'MFE',
#  '10792': 'BUF',
#  '14492': 'RDU',
#  '12451': 'JAX',
#  '13577': 'MYR',
#  '10781': 'BTR',
#  '12278': 'ICT',
#  '14685': 'SAV',
#  '11995': 'GSO',
#  '13485': 'MSN',
#  '11977': 'GRB',
#  '12339': 'IND',
#  '13232': 'MDW',
#  '11259': 'DAL',
#  '10257': 'ALB',
#  '13796': 'OAK',
#  '10140': 'ABQ',
#  '13296': 'MHT',
#  '14570': 'RNO',
#  '14893': 'SMF',
#  '14679': 'SAN',
#  '14524': 'RIC',
#  '12217': 'HSV',
#  '10713': 'BOI',
#  '10208': 'AGS',
#  '11603': 'EUG',
#  '14689': 'SBA',
#  '11315': 'DIK',
#  '13264': 'MFR',
#  '14814': 'SHV',
#  '11308': 'DHN',
#  '11066': 'CMH',
#  '12896': 'LBB',
#  '14307': 'PVD',
#  '14843': 'SJU',
#  '11721': 'FNT',
#  '11140': 'CRP',
#  '10185': 'AEX',
#  '13277': 'MGM',
#  '13342': 'MKE',
#  '11433': 'DTW',
#  '12953': 'LGA',
#  '10599': 'BHM',
#  '12156': 'HLN',
#  '14952': 'SPI',
#  '10620': 'BIL',
#  '11042': 'CLE',
#  '15096': 'SYR',
#  '10408': 'ATW',
#  '15249': 'TLH',
#  '11423': 'DSM',
#  '12915': 'LCH',
#  '13871': 'OMA',
#  '14027': 'PBI',
#  '13244': 'MEM',
#  '11267': 'DAY',
#  '11540': 'ELP',
#  '14576': 'ROC',
#  '10868': 'CAE',
#  '13486': 'MSO',
#  '13476': 'MRY',
#  '14489': 'RDM',
#  '12945': 'LEX',
#  '15607': 'VLD',
#  '10529': 'BDL',
#  '11986': 'GRR',
#  '14635': 'RSW',
#  '10785': 'BTV',
#  '15380': 'TVC',
#  '11996': 'GSP',
#  '10561': 'BFL',
#  '10874': 'CAK',
#  '13367': 'MLI',
#  '10146': 'ABY',
#  '10431': 'AVL',
#  '11973': 'GPT',
#  '10980': 'CHA',
#  '12197': 'HPN',
#  '12323': 'ILM',
#  '11150': 'CSG',
#  '10135': 'ABE',
#  '11617': 'EWN',
#  '13029': 'LNK',
#  '11003': 'CID',
#  '11146': 'CRW',
#  '11577': 'ERI',
#  '15356': 'TTN',
#  '10279': 'AMA',
#  '14908': 'SNA',
#  '14321': 'PWM',
#  '11638': 'FAT',
#  '14828': 'SIT',
#  '12523': 'JNU',
#  '12954': 'LGB',
#  '11481': 'ECP',
#  '12951': 'LFT',
#  '10434': 'AVP',
#  '12448': 'JAN',
#  '14730': 'SDF',
#  '15323': 'TRI',
#  '14252': 'PSC',
#  '11193': 'CVG',
#  '10849': 'BZN',
#  '14193': 'PNS',
#  '14986': 'SRQ',
#  '11641': 'FAY',
#  '12992': 'LIT',
#  '13422': 'MOB',
#  '11612': 'EVV',
#  '11823': 'FWA',
#  '11980': 'GRI',
#  '13290': 'MHK',
#  '10158': 'ACY',
#  '10685': 'BMI',
#  '13377': 'MLU',
#  '11109': 'COS',
#  '11076': 'CMX',
#  '11122': 'CPR',
#  '11865': 'GCC',
#  '14543': 'RKS',
#  '11587': 'ESC',
#  '14457': 'RAP',
#  '12335': 'IMT',
#  '14520': 'RHI',
#  '12343': 'INL',
#  '12129': 'HIB',
#  '12003': 'GTF',
#  '12884': 'LAN',
#  '14633': 'RST',
#  '15048': 'SUX',
#  '12389': 'ISN',
#  '11525': 'EKO',
#  '14262': 'PSP',
#  '12391': 'ISP',
#  '11648': 'FCA',
#  '14696': 'SBN',
#  '10469': 'AZO',
#  '15412': 'TYS',
#  '10731': 'BQK',
#  '10800': 'BUR',
#  '11413': 'DRO',
#  '13433': 'MOT',
#  '11867': 'GCK',
#  '14698': 'SBP',
#  '11537': 'ELM',
#  '11337': 'DLH',
#  '13360': 'MLB',
#  '13076': 'LSE',
#  '14006': 'PAH',
#  '10728': 'BPT',
#  '15401': 'TXK',
#  '13230': 'MDT',
#  '12016': 'GUM',
#  '11067': 'CMI',
#  '11274': 'DBQ',
#  '11921': 'GJT',
#  '13970': 'OTZ',
#  '10779': 'BTM',
#  '14150': 'PLN',
#  '14794': 'SGU',
#  '12511': 'JLN',
#  '12177': 'HOB',
#  '13184': 'MBS',
#  '12007': 'GTR',
#  '14588': 'ROW',
#  '13061': 'LRD',
#  '15041': 'SUN',
#  '14574': 'ROA',
#  '14109': 'PIB',
#  '13241': 'MEI',
#  '12441': 'JAC',
#  '12898': 'LBE',
#  '11695': 'FLG',
#  '14113': 'PIH',
#  '11624': 'EYW',
#  '11503': 'EGE',
#  '10739': 'BRD',
#  '14711': 'SCE',
#  '12819': 'KTN',
#  '15070': 'SWF',
#  '11252': 'DAB',
#  '15024': 'STT',
#  '12280': 'IDA',
#  '14709': 'SCC',
#  '10372': 'ASE',
#  '14674': 'SAF',
#  '10157': 'ACV',
#  '10918': 'CDC',
#  '13933': 'ORH',
#  '10136': 'ABI',
#  '14842': 'SJT',
#  '11049': 'CLL',
#  '13459': 'MQT',
#  '10155': 'ACT',
#  '10581': 'BGR',
#  '13344': 'MKG',
#  '15841': 'WRG',
#  '14098': 'PHF',
#  '15991': 'YAK',
#  '10754': 'BRW',
#  '13873': 'OME',
#  '10333': 'APN',
#  '13127': 'LWS',
#  '12094': 'HDN',
#  '14256': 'PSG',
#  '10154': 'ACK',
#  '10926': 'CDV',
#  '13964': 'OTH',
#  '15027': 'STX',
#  '14905': 'SMX',
#  '11471': 'EAU',
#  '10268': 'ALO',
#  '13541': 'MVY',
#  '10141': 'ABR',
#  '10165': 'ADK',
#  '10577': 'BGM',
#  '10170': 'ADQ',
#  '15497': 'UST',
#  '12265': 'IAG',
#  '14222': 'PPG',
#  '14025': 'PBG',
#  '10666': 'BLI',
#  '16218': 'YUM'}

# %%
dict_airport.values()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-ca7c0f7e719b> in <module>
# ----> 1 dict_airport.values()
#
# NameError: name 'dict_airport' is not defined

# %%
with open('dict_airport.json', 'wb') as fp:
    pickle.dump(dict_airport, fp)
